# %%
1+1
# Out:
# 2

# %% [markdown]
# Ya saben algo de escritura

# %%
x='Leonel'

# %%
print(x)
# Out:
# Leonel

# %% [markdown]
# # Tabla

# %%
import pandas as pd
tabla=pd.DataFrame(data = [[1,1],[2,4],[3,9]],
                  columns =['numero', 'cuadrado'])
tabla
# Out:
#    numero  cuadrado
# 0       1         1
# 1       2         4
# 2       3         9

# %% [markdown]
# # Grafico

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [1,4,9,16,25]

plt.plot (x ,y)
plt.show()

# %% [markdown]
# # Intento de subir img

# %% [markdown]
# ![DSC04204j.jpg](attachment:DSC04204j.jpg)

# %% [markdown]
# # Conclusiones
#
# * primera
# * segunda
# * tercera
